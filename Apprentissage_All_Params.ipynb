# %%
import tensorflow as tf
from skimage import io
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.models import Model
import os
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

import cv2 as cv
from skimage import feature as skif

from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import GridSearchCV, learning_curve, ShuffleSplit
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import decomposition
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Chargement des données

# %%
X_train = np.load("/content/drive/MyDrive/Dataset/anti_spoofing/all_caracts/features_all_train.npy")
y_train = np.load("/content/drive/MyDrive/Dataset/anti_spoofing/all_caracts/labels_all_train.npy")
X_test = np.load("/content/drive/MyDrive/Dataset/anti_spoofing/all_caracts/features_all_test.npy")
y_test = np.load("/content/drive/MyDrive/Dataset/anti_spoofing/all_caracts/labels_all_test.npy")

# %% [markdown]
# # Implémentation des models

# %% [markdown]
# # Courbes d'apprentissage

# %%
def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate 3 plots: the test and training learning curve, the training
    samples vs fit times curve, the fit times vs score curve.

    Parameters
    ----------
    estimator : estimator instance
        An estimator instance implementing `fit` and `predict` methods which
        will be cloned for each validation.

    title : str
        Title for the chart.

    X : array-like of shape (n_samples, n_features)
        Training vector, where ``n_samples`` is the number of samples and
        ``n_features`` is the number of features.

    y : array-like of shape (n_samples) or (n_samples, n_features)
        Target relative to ``X`` for classification or regression;
        None for unsupervised learning.

    axes : array-like of shape (3,), default=None
        Axes to use for plotting the curves.

    ylim : tuple of shape (2,), default=None
        Defines minimum and maximum y-values plotted, e.g. (ymin, ymax).

    cv : int, cross-validation generator or an iterable, default=None
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:

          - None, to use the default 5-fold cross-validation,
          - integer, to specify the number of folds.
          - :term:`CV splitter`,
          - An iterable yielding (train, test) splits as arrays of indices.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : int or None, default=None
        Number of jobs to run in parallel.
        ``None`` means 1 unless in a :obj:`joblib.parallel_backend` context.
        ``-1`` means using all processors. See :term:`Glossary <n_jobs>`
        for more details.

    train_sizes : array-like of shape (n_ticks,)
        Relative or absolute numbers of training examples that will be used to
        generate the learning curve. If the ``dtype`` is float, it is regarded
        as a fraction of the maximum size of the training set (that is
        determined by the selected validation method), i.e. it has to be within
        (0, 1]. Otherwise it is interpreted as absolute sizes of the training
        sets. Note that for classification the number of samples usually have
        to be big enough to contain at least one sample from each class.
        (default: np.linspace(0.1, 1.0, 5))
    """
    if axes is None:
        _, axes = plt.subplots(1, 3, figsize=(20, 5))

    axes[0].set_title(title)
    if ylim is not None:
        axes[0].set_ylim(*ylim)
    axes[0].set_xlabel("Training examples")
    axes[0].set_ylabel("Score")

    train_sizes, train_scores, test_scores, fit_times, _ = \
        learning_curve(estimator, X, y, cv=cv, n_jobs=n_jobs,
                       train_sizes=train_sizes,
                       return_times=True)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    fit_times_mean = np.mean(fit_times, axis=1)
    fit_times_std = np.std(fit_times, axis=1)

    # Plot learning curve
    axes[0].grid()
    axes[0].fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    axes[0].fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    axes[0].plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    axes[0].plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    axes[0].legend(loc="best")

    # Plot n_samples vs fit_times
    axes[1].grid()
    axes[1].plot(train_sizes, fit_times_mean, 'o-')
    axes[1].fill_between(train_sizes, fit_times_mean - fit_times_std,
                         fit_times_mean + fit_times_std, alpha=0.1)
    axes[1].set_xlabel("Training examples")
    axes[1].set_ylabel("fit_times")
    axes[1].set_title("Scalability of the model")

    # Plot fit_time vs score
    axes[2].grid()
    axes[2].plot(fit_times_mean, test_scores_mean, 'o-')
    axes[2].fill_between(fit_times_mean, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1)
    axes[2].set_xlabel("fit_times")
    axes[2].set_ylabel("Score")
    axes[2].set_title("Performance of the model")

    return plt

# %% [markdown]
# # Réduction des dimentions

# %%
X_train[0].shape
# Out:
# (433,)

# %%
# Calcul des composantes principales
n_comp_init = X_train[0].shape[0]
pca = decomposition.PCA(n_components=n_comp_init)
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=433, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 6))
axes.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
total = 0
i = 30
for j in range(i):
  total += pca.explained_variance_ratio_[j]

print('{} demnsions expliquent {}% de données'.format(i, total))
# Out:
# 30 demnsions expliquent 0.9801716597750637% de données

# %%
n_comp = 30
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_pca.sav'
pickle.dump(pca, open(filename, 'wb'))

# %% [markdown]
# ## Model SVM

# %%
model_svm = make_pipeline(StandardScaler(), SVC())

params = {'svc__kernel': ['rbf', 'linear'],
         'svc__C': [1e3, 1, 0.5]}

grid = GridSearchCV(model_svm, params, cv=5)

print(grid)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('svc',
#                                         SVC(C=1.0, break_ties=False,
#                                             cache_size=200, class_weight=None,
#                                             coef0=0.0,
#                                             decision_function_shape='ovr',
#                                             degree=3, gamma='scale',
#                                             kernel='rbf', max_iter=-1,
#                                             probability=False,
#                                             random_state=None, shrinking=True,
#                                             tol=0.001, verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'svc__C': [1000.0, 1, 0.5],
#                          'svc__kernel': ['rbf', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Formation du model
grid.fit(X_train_pca, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('svc',
#                                         SVC(C=1.0, break_ties=False,
#                                             cache_size=200, class_weight=None,
#                                             coef0=0.0,
#                                             decision_function_shape='ovr',
#                                             degree=3, gamma='scale',
#                                             kernel='rbf', max_iter=-1,
#                                             probability=False,
#                                             random_state=None, shrinking=True,
#                                             tol=0.001, verbose=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'svc__C': [1000.0, 1, 0.5],
#                          'svc__kernel': ['rbf', 'linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Meilleurs paramètres
grid.best_params_
# Out:
# {'svc__C': 1, 'svc__kernel': 'rbf'}

# %%
# Score sur les données d'entrainement
grid.score(X_train_pca, y_train)
# Out:
# 0.9521586931155193

# %%
# Score sur les données de test
grid.score(X_test_pca, y_test)
# Out:
# 0.8765

# %%
# Résultat obtenus
print(classification_report(y_test, grid.predict(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.85      0.91      0.88      1000
#        Spoof       0.91      0.84      0.87      1000
#
#     accuracy                           0.88      2000
#    macro avg       0.88      0.88      0.88      2000
# weighted avg       0.88      0.88      0.88      2000

# %%
# Matrice de confusion sur les données de test
confusion = confusion_matrix(y_test, grid.predict(X_test_pca))
confusion
# Out:
# array([[914,  86],
#        [161, 839]])

# %%
model_svm = grid.best_estimator_
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_svm.sav'
pickle.dump(model_svm, open(filename, 'wb'))

# %% [markdown]
# ## Logistic regression

# %%
model_lr = make_pipeline(StandardScaler(), LogisticRegression())

params = {'logisticregression__C': [0.5, 1, 1e3]}

grid_lr = GridSearchCV(model_lr, params, cv=5)

print(grid_lr)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('logisticregression',
#                                         LogisticRegression(C=1.0,
#                                                            class_weight=None,
#                                                            dual=False,
#                                                            fit_intercept=True,
#                                                            intercept_scaling=1,
#                                                            l1_ratio=None,
#                                                            max_iter=100,
#                                                            multi_class='auto',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='lbfgs',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'logisticregression__C': [0.5, 1, 1000.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Formation du model
grid_lr.fit(X_train_pca, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('logisticregression',
#                                         LogisticRegression(C=1.0,
#                                                            class_weight=None,
#                                                            dual=False,
#                                                            fit_intercept=True,
#                                                            intercept_scaling=1,
#                                                            l1_ratio=None,
#                                                            max_iter=100,
#                                                            multi_class='auto',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='lbfgs',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'logisticregression__C': [0.5, 1, 1000.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Meilleurs paramètres
grid_lr.best_params_
# Out:
# {'logisticregression__C': 0.5}

# %%
# Score sur les données d'entrainement
grid_lr.score(X_train_pca, y_train)
# Out:
# 0.9148191365227538

# %%
# Score sur les données de test
grid_lr.score(X_test_pca, y_test)
# Out:
# 0.8845

# %%
# Résultat obtenus
print(classification_report(y_test, grid_lr.predict(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.87      0.91      0.89      1000
#        Spoof       0.90      0.86      0.88      1000
#
#     accuracy                           0.88      2000
#    macro avg       0.89      0.88      0.88      2000
# weighted avg       0.89      0.88      0.88      2000

# %%
# Matrice de confusion sur les données de test
confusion = confusion_matrix(y_test, grid_lr.predict(X_test_pca))
confusion
# Out:
# array([[908,  92],
#        [139, 861]])

# %%
model_lr = grid_lr.best_estimator_
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_lr.sav'
pickle.dump(model_lr, open(filename, 'wb'))

# %% [markdown]
# ## Random Forest

# %%
model_rf = make_pipeline(StandardScaler(), RandomForestClassifier())

params = {}

grid_rf = GridSearchCV(model_rf, params, cv=5)

print(grid_rf)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(bootstrap=True,
#                                                                ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features='auto',
#                                                                max_leaf_nodes=None,
#                                                                max_samples=None,
#                                                                min_impurity_decrease=0.0,
#                                                                min_impurity_split=None,
#                                                                min_samples_leaf=1,
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=None,
#                                                                oob_score=False,
#                                                                random_state=None,
#                                                                verbose=0,
#                                                                warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Formation du model
grid_rf.fit(X_train_pca, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(bootstrap=True,
#                                                                ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features='auto',
#                                                                max_leaf_nodes=None,
#                                                                max_samples=None,
#                                                                min_impurity_decrease=0.0,
#                                                                min_impurity_split=None,
#                                                                min_samples_leaf=1,
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=None,
#                                                                oob_score=False,
#                                                                random_state=None,
#                                                                verbose=0,
#                                                                warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Meilleurs paramètres
grid_rf.best_params_
# Out:
# {}

# %%
# Score sur les données d'entrainement
grid_rf.score(X_train_pca, y_train)
# Out:
# 1.0

# %%
# Score sur les données de test
grid_rf.score(X_test_pca, y_test)
# Out:
# 0.8665

# %%
# Résultat obtenus
print(classification_report(y_test, grid_rf.predict(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.84      0.91      0.87      1000
#        Spoof       0.90      0.83      0.86      1000
#
#     accuracy                           0.87      2000
#    macro avg       0.87      0.87      0.87      2000
# weighted avg       0.87      0.87      0.87      2000

# %%
# Matrice de confusion sur les données de test
confusion = confusion_matrix(y_test, grid_rf.predict(X_test_pca))
confusion
# Out:
# array([[907,  93],
#        [174, 826]])

# %%
model_rf = grid_rf.best_estimator_
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_rf.sav'
pickle.dump(model_rf, open(filename, 'wb'))

# %% [markdown]
# ## Decision Tree

# %%
model_dt = make_pipeline(StandardScaler(), DecisionTreeClassifier())

params = {}

grid_dt = GridSearchCV(model_dt, params, cv=5)

print(grid_dt)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features=None,
#                                                                max_leaf_nodes=None,
#                                                                min_impurity_decrease=0.0,
#                                                                min_impurity_split=None,
#                                                                min_samples_leaf=1,
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                presort='deprecated',
#                                                                random_state=None,
#                                                                splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Formation du model
grid_dt.fit(X_train_pca, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                class_weight=None,
#                                                                criterion='gini',
#                                                                max_depth=None,
#                                                                max_features=None,
#                                                                max_leaf_nodes=None,
#                                                                min_impurity_decrease=0.0,
#                                                                min_impurity_split=None,
#                                                                min_samples_leaf=1,
#                                                                min_samples_split=2,
#                                                                min_weight_fraction_leaf=0.0,
#                                                                presort='deprecated',
#                                                                random_state=None,
#                                                                splitter='best'))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Meilleurs paramètres
grid_dt.best_params_
# Out:
# {}

# %%
# Score sur les données d'entrainement
grid_dt.score(X_train_pca, y_train)
# Out:
# 1.0

# %%
# Score sur les données de test
grid_dt.score(X_test_pca, y_test)
# Out:
# 0.8235

# %%
# Résultat obtenus
print(classification_report(y_test, grid_dt.predict(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.81      0.85      0.83      1000
#        Spoof       0.84      0.80      0.82      1000
#
#     accuracy                           0.82      2000
#    macro avg       0.82      0.82      0.82      2000
# weighted avg       0.82      0.82      0.82      2000

# %%
# Matrice de confusion sur les données de test
confusion = confusion_matrix(y_test, grid_dt.predict(X_test_pca))
confusion
# Out:
# array([[848, 152],
#        [201, 799]])

# %%
model_dt = grid_dt.best_estimator_
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_dt.sav'
pickle.dump(model_dt, open(filename, 'wb'))

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDClassifier

model_sgd = make_pipeline(StandardScaler(), SGDClassifier())

params = {}

grid_sgd = GridSearchCV(model_sgd, params, cv=5)

print(grid_sgd)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('sgdclassifier',
#                                         SGDClassifier(alpha=0.0001,
#                                                       average=False,
#                                                       class_weight=None,
#                                                       early_stopping=False,
#                                                       epsilon=0.1, eta0=0.0,
#                                                       fit_intercept=True,
#                                                       l1_ratio=0.15,
#                                                       learning_rate='optimal',
#                                                       loss='hinge',
#                                                       max_iter=1000,
#                                                       n_iter_no_change=5,
#                                                       n_jobs=None, penalty='l2',
#                                                       power_t=0.5,
#                                                       random_state=None,
#                                                       shuffle=True, tol=0.001,
#                                                       validation_fraction=0.1,
#                                                       verbose=0,
#                                                       warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Formation du model
grid_sgd.fit(X_train_pca, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('standardscaler',
#                                         StandardScaler(copy=True,
#                                                        with_mean=True,
#                                                        with_std=True)),
#                                        ('sgdclassifier',
#                                         SGDClassifier(alpha=0.0001,
#                                                       average=False,
#                                                       class_weight=None,
#                                                       early_stopping=False,
#                                                       epsilon=0.1, eta0=0.0,
#                                                       fit_intercept=True,
#                                                       l1_ratio=0.15,
#                                                       learning_rate='optimal',
#                                                       loss='hinge',
#                                                       max_iter=1000,
#                                                       n_iter_no_change=5,
#                                                       n_jobs=None, penalty='l2',
#                                                       power_t=0.5,
#                                                       random_state=None,
#                                                       shuffle=True, tol=0.001,
#                                                       validation_fraction=0.1,
#                                                       verbose=0,
#                                                       warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None, param_grid={},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# Score sur les données d'entrainement
grid_sgd.score(X_train_pca, y_train)
# Out:
# 0.9046507751291882

# %%
# Score sur les données de test
grid_sgd.score(X_test_pca, y_test)
# Out:
# 0.8765

# %%
# Résultat obtenus
print(classification_report(y_test, grid_sgd.predict(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.85      0.92      0.88      1000
#        Spoof       0.91      0.83      0.87      1000
#
#     accuracy                           0.88      2000
#    macro avg       0.88      0.88      0.88      2000
# weighted avg       0.88      0.88      0.88      2000

# %%
# Matrice de confusion sur les données de test
confusion = confusion_matrix(y_test, grid_sgd.predict(X_test_pca))
confusion
# Out:
# array([[920,  80],
#        [167, 833]])

# %%
model_sgd = grid_sgd.best_estimator_
filename = '/content/drive/MyDrive/Dataset/anti_spoofing/models/all_sgd.sav'
pickle.dump(model_sgd, open(filename, 'wb'))

# %% [markdown]
# ## Neural network

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(n_comp)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               7936
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 49,153
# Trainable params: 49,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train_pca, y_train, batch_size=32, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 150/150 [==============================] - 2s 6ms/step - loss: 0.3277 - accuracy: 0.8458 - val_loss: 0.2612 - val_accuracy: 0.8917
# Epoch 2/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.2273 - accuracy: 0.9081 - val_loss: 0.2713 - val_accuracy: 0.8900
# Epoch 3/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.2219 - accuracy: 0.9071 - val_loss: 0.2401 - val_accuracy: 0.9033
# Epoch 4/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1974 - accuracy: 0.9278 - val_loss: 0.2359 - val_accuracy: 0.9050
# Epoch 5/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.2008 - accuracy: 0.9249 - val_loss: 0.2362 - val_accuracy: 0.9117
# Epoch 6/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9338 - val_loss: 0.2315 - val_accuracy: 0.9092
# Epoch 7/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1716 - accuracy: 0.9360 - val_loss: 0.2266 - val_accuracy: 0.9083
# Epoch 8/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9330 - val_loss: 0.2312 - val_accuracy: 0.9158
# Epoch 9/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9393 - val_loss: 0.2416 - val_accuracy: 0.9075
# Epoch 10/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1610 - accuracy: 0.9362 - val_loss: 0.2321 - val_accuracy: 0.9150
# Epoch 11/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1645 - accuracy: 0.9371 - val_loss: 0.2411 - val_accuracy: 0.9150
# Epoch 12/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1483 - accuracy: 0.9398 - val_loss: 0.2380 - val_accuracy: 0.9183
# Epoch 13/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1338 - accuracy: 0.9468 - val_loss: 0.2347 - val_accuracy: 0.9167
# Epoch 14/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9450 - val_loss: 0.2462 - val_accuracy: 0.9158
# Epoch 15/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9443 - val_loss: 0.2489 - val_accuracy: 0.9192
# Epoch 16/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9537 - val_loss: 0.2394 - val_accuracy: 0.9150
# Epoch 17/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9599 - val_loss: 0.2639 - val_accuracy: 0.9083
# Epoch 18/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9536 - val_loss: 0.2727 - val_accuracy: 0.9150
# Epoch 19/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1053 - accuracy: 0.9608 - val_loss: 0.2569 - val_accuracy: 0.9150
# Epoch 20/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9629 - val_loss: 0.3044 - val_accuracy: 0.9117
# Epoch 21/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9677 - val_loss: 0.2780 - val_accuracy: 0.9133
# Epoch 22/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9620 - val_loss: 0.3060 - val_accuracy: 0.9092
# Epoch 23/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9716 - val_loss: 0.2726 - val_accuracy: 0.9175
# Epoch 24/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0820 - accuracy: 0.9659 - val_loss: 0.3071 - val_accuracy: 0.9117
# Epoch 25/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9707 - val_loss: 0.2937 - val_accuracy: 0.9167
# Epoch 26/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.9656 - val_loss: 0.3129 - val_accuracy: 0.9100
# Epoch 27/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9733 - val_loss: 0.2966 - val_accuracy: 0.9125
# Epoch 28/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9717 - val_loss: 0.3329 - val_accuracy: 0.9125
# Epoch 29/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0579 - accuracy: 0.9791 - val_loss: 0.3088 - val_accuracy: 0.9133
# Epoch 30/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9832 - val_loss: 0.3292 - val_accuracy: 0.9092
# Epoch 31/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0523 - accuracy: 0.9831 - val_loss: 0.3298 - val_accuracy: 0.9192
# Epoch 32/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9739 - val_loss: 0.3332 - val_accuracy: 0.9192
# Epoch 33/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9832 - val_loss: 0.3678 - val_accuracy: 0.9150
# Epoch 34/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9775 - val_loss: 0.3407 - val_accuracy: 0.9133
# Epoch 35/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.3829 - val_accuracy: 0.9058
# Epoch 36/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9851 - val_loss: 0.3868 - val_accuracy: 0.9083
# Epoch 37/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0499 - accuracy: 0.9821 - val_loss: 0.4178 - val_accuracy: 0.9117
# Epoch 38/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9838 - val_loss: 0.3708 - val_accuracy: 0.9167
# Epoch 39/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0482 - accuracy: 0.9813 - val_loss: 0.3695 - val_accuracy: 0.9183
# Epoch 40/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9845 - val_loss: 0.4249 - val_accuracy: 0.9133
# Epoch 41/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9882 - val_loss: 0.4129 - val_accuracy: 0.9133
# Epoch 42/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9878 - val_loss: 0.4617 - val_accuracy: 0.9083
# Epoch 43/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9848 - val_loss: 0.4178 - val_accuracy: 0.9125
# Epoch 44/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0348 - accuracy: 0.9867 - val_loss: 0.4234 - val_accuracy: 0.9133
# Epoch 45/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9897 - val_loss: 0.4413 - val_accuracy: 0.9192
# Epoch 46/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 0.9881 - val_loss: 0.4824 - val_accuracy: 0.9083
# Epoch 47/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 0.9863 - val_loss: 0.4289 - val_accuracy: 0.9133
# Epoch 48/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 0.9839 - val_loss: 0.4723 - val_accuracy: 0.9100
# Epoch 49/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 0.9884 - val_loss: 0.4429 - val_accuracy: 0.9217
# Epoch 50/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.0362 - accuracy: 0.9860 - val_loss: 0.4317 - val_accuracy: 0.9242

# %%
loss0,accuracy0 = model.evaluate(X_test_pca, y_test, batch_size=32)

print("Test loss: {:.2f}".format(loss0))
print("Test accuracy: {:.2f}".format(accuracy0))
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 1.1962 - accuracy: 0.8460
# Test loss: 1.20
# Test accuracy: 0.85

# %%
# Résultat obtenus
print(classification_report(y_test, model.predict_classes(X_test_pca), target_names=['Live', 'Spoof']))
# Out:
#               precision    recall  f1-score   support
#
#         Live       0.80      0.91      0.86      1000
#        Spoof       0.90      0.78      0.83      1000
#
#     accuracy                           0.85      2000
#    macro avg       0.85      0.85      0.85      2000
# weighted avg       0.85      0.85      0.85      2000
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Courbe apprentissage meilleur model (Logistic Regression)

# %%
best_model = model_lr

title = "Courbes d'apprentissage LBF + Transfert_learning (SVM)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

plot_learning_curve(best_model, title, X_train_pca, y_train, axes=None, ylim=(0.0, 1.01),
                    cv=cv, n_jobs=4)

plt.show()

# %% [markdown]
# # Test

# %%
predire = {0: "Live", 1: "Spoof"}

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
from skimage import io
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.models import Model
import cv2 as cv

# %%
model_loaded = tf.keras.models.load_model('/content/drive/MyDrive/Dataset/anti_spoofing/feature_extraction.h5')
layer_name = 'dense_6'
intermediate_layer_model = Model(inputs=model_loaded.input, outputs=model_loaded.get_layer(layer_name).out
                                 put)

# %%
  image_path_0 = '/content/drive/MyDrive/Dataset/anti_spoofing/images/0.jpg'
image_path_1 = '/content/drive/MyDrive/Dataset/anti_spoofing/images/1.jpg'
image_path_2 = '/content/drive/MyDrive/Dataset/anti_spoofing/images/2.jpg'
image_path_3 = '/content/drive/MyDrive/Dataset/anti_spoofing/images/3.jpg'
image_path_4 = '/content/drive/MyDrive/Dataset/anti_spoofing/images/4.png'

liste_label = [1, 0, 0, 1, 0]

# Lecture des images
images = [cv.imread(image_path) for image_path in [image_path_0, image_path_1, image_path_2, image_path_3, image_path_4]]

# Extraction de LBP
def extract_lbp_test(im):
  image_y = cv.cvtColor(im, cv.COLOR_BGR2YCrCb)
  lbp_y, y_h = lbp_histogram(image_y[:,:,0]) # y channel
  lbp_cb, cb_h = lbp_histogram(image_y[:,:,1]) # cb channel
  lbp_cr, cr_h = lbp_histogram(image_y[:,:,2]) # cr channel
  feature_lbp = np.concatenate((y_h, cb_h, cr_h))
  return feature_lbp

features_lbp = [extract_lbp_test(im) for im in images]

# Extraction de caractéristiques de tensorflow
def extract_tf_test(im):
  img = tf.image.resize(im, [224, 224], method='nearest')
  X = image.img_to_array(img)
  X = np.expand_dims(X, axis=0)
  images = np.vstack([X])
  images = images / 255
  feature_tensorflow = intermediate_layer_model.predict([images])[0]
  return feature_tensorflow

features_tf = [extract_tf_test(im) for im in images]


features_final = [np.concatenate((f_lbp, f_tf), axis=None) for f_lbp, f_tf in zip(features_lbp, features_tf)]

images_test_ = pca.transform(features_final)

plt.figure(figsize=(15, 10))
for i, im in enumerate(images_test_):
    ax = plt.subplot(1, 5, i + 1)
    plt.imshow(cv.cvtColor(images[i], cv.COLOR_BGR2RGB))
    plt.title('Label : {}'.format(predire[liste_label[i]]) + '\nPrédiction : {}'.format(predire[best_model.predict(images_test_)[i]]))
    plt.axis("off")

plt.show()
